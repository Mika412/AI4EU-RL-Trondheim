# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10000,1000)
y = np.array([-44000, -41250, -39900, -37750, -38250, -37750, -37100, -37000, -36200, -36250])

# %%
plt.figure()

plt.plot(x,y)

plt.ylabel(r'Map aggregated pollution level ($\mu g/m^3$)')
plt.xlabel('Episodes')

plt.savefig('figs/rl_reward.pdf',bbox_inches='tight')
